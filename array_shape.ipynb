# %%
from matplotlib import pyplot as plt

# %%
from benchmark import bench_suite

# %%
size = 1000

# %%
for name, func in bench_suite.funcs.items():
    b, a = func(size)
    plt.plot(b)
    plt.title(name)
    plt.show()
